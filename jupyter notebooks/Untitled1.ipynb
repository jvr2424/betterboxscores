# %%
import buildrotation

# %%
buildrotation.build_rotation('0022000141', 'UAT', 'DET' )
# Out:
# C:\Users\joera\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\util\_decorators.py:208: FutureWarning: Passing timedelta64-dtype data is deprecated, will raise a TypeError in a future version
#   return func(*args, **kwargs)
# ('UATrotation.png', 'DETrotation.png')
